# %% [markdown]
# ## Loading Pandas DataFrames and Charting in Matplolib
#
# #The following is a demonstration of my experience in using various libraries including pandas, matplotlib, numpy, seaborn, and sci-kit learn. This was an assignment from my Masters of Data Science program to import types of files inlcuding xlsx, csv, txt, and json, and then create a scatterplot with the associated linear regression based on the data. The first graphic is the result of my code where the second graphic is the sample output.
#
# ### Assignment Outcomes
# Demonstrated ability to:
# * Load data files of various formats into pandas dataframes.
# * Perform basic statistical calculations and save results to variables.
# * Use various libraries and modules to perform linear regresion.
# * Create basic Matplotlib charts with multiple plots and annotations.
# * Export all data to a csv file for future use.
# * Combine four individuals plots into one figure with four subplots.

# %% [markdown]
# # Load necessary libraries, modules, and magics
# * Place all import and magics needed in the next cell.

# %%
# Import dependencies and magics

import matplotlib.pyplot as plt    
import numpy as np                 
import math                        
import seaborn as sns      
import pandas as pd
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# # Loading from Excel
# * Load the file *data1.xlsx* to a dataframe named `df1`.
# * The two data columns should be named `x1` and `y1`.
# * Use pandas' describe() to those two variables.
# * Calculate a variety of statistics as described in the cells below. Use any methods and functions you prefer.
# * Plot a scatter plot of the two variables.
# * Overlay a regression line on the plot calculated from the two variables.
# * Add annotations so that the means, sample variances, correlation, and regression equation are in a box in the upper left corner of the figure.

# %%
# Load the data file to a data frame named df1. 

file = 'data1.xlsx'
df1 = pd.read_excel(file)

df1
# Out:
#     x1     y1
# 0   10   8.04
# 1    8   6.95
# 2   13   7.58
# 3    9   8.81
# 4   11   8.33
# 5   14   9.96
# 6    6   7.24
# 7    4   4.26
# 8   12  10.84
# 9    7   4.82
# 10   5   5.68

# %%
# describe the series in the dataframe

df1.describe()
# Out:
#               x1         y1
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
# Calculate the following by replacing the 0 with some formula.

mean_x1 = df1['x1'].mean()       # mean
mean_y1 = df1['y1'].mean()       # mean
svar_x1 = df1['x1'].var()       # sample variance
svar_y1 = df1['y1'].var()       # sample variance
corr_x1y1 = df1['x1'].corr(df1['y1'])     # correlation

# %%
# Print out the results (Do not change this code)
print(f'mean_x1: {mean_x1:.3f}\tmean_y1: {mean_y1:.3f}')     # mean'
print(f'svar_x1: {svar_x1:.3f}\tsvar_y1: {svar_y1:.3f}') 
print(f'corr: {corr_x1y1:.3f}')
# Out:
# mean_x1: 9.000	mean_y1: 7.501
# svar_x1: 11.000	svar_y1: 4.127
# corr: 0.816

# %%
X1 = df1['x1']
Y1 = df1['y1']
plt.scatter(X1,Y1);

# %%
x1 = df1['x1'].tolist()
y1 = df1['y1'].tolist()

print(x1)
print(y1)
# Out:
# [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
# [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

# %%
plt.scatter(x1, y1)
plt.show()

# %%
from scipy import stats

# %%
slope, intercept, r, p, std_err = stats.linregress(x1, y1)

# %%
print('slope: ' + str(slope))
print('intercept: ' + str(intercept))
print('r: ' + str(r))
print('p: ' + str(p))
print('std_err: ' + str(std_err))
# Out:
# slope: 0.5000909090909091
# intercept: 3.0000909090909103
# r: 0.8164205163448399
# p: 0.00216962887307879
# std_err: 0.11790550059563408

# %%
# Calculate a linear regression line;  capture the following results
d1_const = intercept    # regression line constant
x1_coef = slope     # x coefficient

# %%
# Print out the results of the regression equation (Do not change this code)
print(f'y = {d1_const:.2f} + {x1_coef:.2f}x')
# Out:
# y = 3.00 + 0.50x

# %%
# Plot it!
# plot x and y as a scatter plot  (dots should be blue)
# On the same chart, plot the regression line without marker (line should be black)
# Choose any style you desire, include x and y axis labels and a title that includes the file name
# Annotate with a box in the upper left corner of the grid as described above

def myfunc(x1):
  return slope * x1 + intercept

mymodel = list(map(myfunc, x1))

fig, ax = plt.subplots(figsize = (12, 10))
plt.xticks (fontsize= 25 ) 
plt.yticks (fontsize= 25 ) 

plt.scatter(x1, y1, s=100, color = 'blue')
plt.plot(x1, mymodel, color = 'black')
plt.title('data1.xlsx', fontsize=25)

box_style=dict(boxstyle='round', facecolor='wheat', alpha=0.5)

ax1= plt.text(4, 10.5, 'mean_x1: 9.00', fontsize = 15, bbox= box_style)
ax2= plt.text(4, 10.0, 'mean_y1: 7.50', fontsize = 15, bbox= box_style)
ax3=plt.text(4, 9.5, 'svar_x1: 11.00', fontsize = 15, bbox= box_style)
ax4=plt.text(4, 9.0,'svar_y1: 4.13', fontsize = 15, bbox=box_style)
ax5=plt.text(4, 8.5, 'corr: 0.82', fontsize = 15, bbox=box_style)

plt.ylabel('y data', fontsize=20)
plt.xlabel('x data', fontsize=20)


plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ex 6A-2 Loading from CSV
# * Load the file *data2.csv* to a dataframe named `df2`.
# * The two data columns should be named `x2` and `y2` and are the first row in the file.
# * Use pandas' describe() to those two variables.
# * Calculate a variety of statistics as described in the cells below. Use any methods and functions you prefer.
# * Plot a scatter plot of the two variables.
# * Overlay a regression line on the plot calculated from the two variables.
# * Add annotations so that the means, sample variances, correlation, and regression equation are in a box in the upper left corner of the figure.

# %%
# Load the data file to a data frame named df2. 

file2 = 'data2.csv'
df2 = pd.read_csv(file2)

df2
# Out:
#     x2    y2
# 0   10  9.14
# 1    8  8.14
# 2   13  8.74
# 3    9  8.77
# 4   11  9.26
# 5   14  8.10
# 6    6  6.13
# 7    4  3.10
# 8   12  9.13
# 9    7  7.26
# 10   5  4.74

# %%
# describe the series in the dataframe
df2.describe()
# Out:
#               x2         y2
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
# Calculate the following by replacing the 0 with some formula.

mean_x2 = df2['x2'].mean()       # mean
mean_y2 = df2['y2'].mean()       # mean
svar_x2 = df2['x2'].var()       # sample variance
svar_y2 = df2['y2'].var()       # sample variance
corr_x2y2 = df2['x2'].corr(df2['y2'])     # correlation

# %%
# Print out the results (Do not change this code)
print(f'mean_x2: {mean_x2:.3f}\tmean_y2: {mean_y2:.3f}')     # mean'
print(f'svar_x2: {svar_x2:.3f}\tsvar_y2: {svar_y2:.3f}') 
print(f'corr: {corr_x2y2:.3f}')
# Out:
# mean_x2: 9.000	mean_y2: 7.501
# svar_x2: 11.000	svar_y2: 4.128
# corr: 0.816

# %%
X2 = df2['x2']
Y2 = df2['y2']
plt.scatter(X2,Y2);

# %%
x2 = df2['x2'].tolist()
y2 = df2['y2'].tolist()

print(x2)
print(y2)
# Out:
# [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
# [9.14, 8.14, 8.74, 8.77, 9.26, 8.1, 6.13, 3.1, 9.13, 7.26, 4.74]

# %%
slope2, intercept2, r2, p2, std_err2 = stats.linregress(x2, y2)

# %%
print('slope2: ' + str(slope2))
print('intercept2: ' + str(intercept2))
print('r2: ' + str(r2))
print('p2: ' + str(p2))
print('std_err2: ' + str(std_err2))
# Out:
# slope2: 0.5000000000000001
# intercept2: 3.000909090909089
# r2: 0.816236506000243
# p2: 0.0021788162369107845
# std_err2: 0.11796374596764074

# %%
# Calculate a linear regression line;  capture the following results
d2_const = intercept2     # regression line constant
x2_coef = slope2     # x coefficient

# %%
# Print out the results of the regression equation (Do not change this code)
print(f'y = {d2_const:.2f} + {x2_coef:.2f}x')
# Out:
# y = 3.00 + 0.50x

# %%
# Plot it!
# plot x and y as a scatter plot  (dots should be orange)
# On the same chart, plot the regression line without marker (line should be black)
# Choose any style you desire, include x and y axis labels and a title that includes the file name
# Annotate with a box in the upper left corner of the grid as described above

def myfunc2(x2):
  return slope * x2 + intercept

mymodel = list(map(myfunc2, x2))

fig, ax = plt.subplots(figsize = (12, 10))
plt.xticks (fontsize= 20 ) 
plt.yticks (fontsize= 20 ) 

plt.scatter(x2, y2, s=150, color = 'orange', )
plt.plot(x2, mymodel, color = 'black')
plt.title('data2.csv', fontsize=30)

ax1= plt.text(4, 10.0, 'mean_x1: 9.00', fontsize = 15, bbox= box_style)
ax2= plt.text(4, 9.5, 'mean_y1: 7.50', fontsize = 15, bbox= box_style)
ax3=plt.text(4, 9.0, 'svar_x1: 11.00', fontsize = 15, bbox= box_style)
ax4=plt.text(4, 8.5,'svar_y1: 4.13', fontsize = 15, bbox=box_style)
ax5=plt.text(4, 8.0, 'corr: 0.82', fontsize = 15, bbox=box_style)

plt.ylabel('y data', fontsize=20)
plt.xlabel('x data', fontsize=20)


plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ex 6A-3 Loading from txt
# * Load the file *data3.txt* to a dataframe named `df3`.
# * There are two numbers in each row separated by a space. Create two lists: one for the first element of each row and one for the second element.
# * Convert each to a list then convert those lists to pandas series names `x3` and `y3`.
# * Use pandas' describe() to those two variables.
# * Calculate a variety of statistics as described in the cells below. Use any methods and functions you prefer.
# * Plot a scatter plot of the two variables.
# * Overlay a regression line on the plot calculated from the two variables.
# * Add annotations so that the means, sample variances, correlation, and regression equation are in a box in the upper left corner of the figure.

# %%
# Load the data file to a data frame named df3. 

file3 = open('data3.txt')
list = []
for line in file3:
    list.append([ float(x) for x in line.split()])


list1 = [ x[0] for x in list]
list2 = [ x[1] for x in list]

print(list1)
print(list2)
# Out:
# [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
# [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

# %%
data = []
data.append(list1)
data.append(list2)

df3 = pd.DataFrame(data).transpose()
df3.columns=['x3', 'y3']

df3
# Out:
#       x3     y3
# 0   10.0   7.46
# 1    8.0   6.77
# 2   13.0  12.74
# 3    9.0   7.11
# 4   11.0   7.81
# 5   14.0   8.84
# 6    6.0   6.08
# 7    4.0   5.39
# 8   12.0   8.15
# 9    7.0   6.42
# 10   5.0   5.73

# %%
# describe the series in the dataframe

df3.describe()
# Out:
#               x3         y3
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
# Calculate the following by replacing the 0 with some formula.

mean_x3 = df3['x3'].mean()       # mean
mean_y3 = df3['y3'].mean()       # mean
svar_x3 = df3['x3'].var()       # sample variance
svar_y3 = df3['y3'].var()       # sample variance
corr_x3y3 = df3['x3'].corr(df3['y3'])     # correlation

# %%
# Print out the results (Do not change this code)
print(f'mean_x3: {mean_x3:.3f}\tmean_y3: {mean_y3:.3f}')     # mean'
print(f'svar_x3: {svar_x3:.3f}\tsvar_y3: {svar_y3:.3f}') 
print(f'corr: {corr_x3y3:.3f}')
# Out:
# mean_x3: 9.000	mean_y3: 7.500
# svar_x3: 11.000	svar_y3: 4.123
# corr: 0.816

# %%
X3 = df3['x3']
Y3 = df3['y3']
plt.scatter(X3,Y3);

# %%
x3 = df3['x3'].tolist()
y3 = df3['y3'].tolist()

print(x3)
print(y3)
# Out:
# [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
# [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]

# %%
slope3, intercept3, r3, p3, std_err3 = stats.linregress(x3, y3)

# %%
print('slope3: ' + str(slope3))
print('intercept3: ' + str(intercept3))
print('r3: ' + str(r3))
print('p3: ' + str(p3))
print('std_err3: ' + str(std_err3))
# Out:
# slope3: 0.4997272727272729
# intercept3: 3.002454545454544
# r3: 0.8162867394895984
# p3: 0.002176305279228015
# std_err3: 0.11787766222100221

# %%
# Calculate a linear regression line;  capture the following results
d3_const = intercept3     # regression line constant
x3_coef = slope3     # x coefficient

# %%
# Print out the results of the regression equation (Do not change this code)
print(f'y = {d3_const:.2f} + {x3_coef:.2f}x')
# Out:
# y = 3.00 + 0.50x

# %%
# Plot it!
# plot x and y as a scatter plot  (dots should be red)
# On the same chart, plot the regression line without marker (line should be black)
# Choose any style you desire, include x and y axis labels and a title that includes the file name
# Annotate with a box in the upper left corner of the grid as described above

fig, ax = plt.subplots(figsize = (12, 10))
plt.xticks (fontsize= 20 ) 
plt.yticks (fontsize= 20 )

ax.scatter(x3, y3, s=100, color="r")

b, a = np.polyfit(x3, y3, deg=1)

xseq = np.linspace(4, 15)

plt.title('data3.txt', fontsize = 30)

ax1= plt.text(4, 12.0, 'mean_x1: 9.00', fontsize = 15, bbox= box_style)
ax2= plt.text(4, 11.5, 'mean_y1: 7.50', fontsize = 15, bbox= box_style)
ax3=plt.text(4, 11.0, 'svar_x1: 11.00', fontsize = 15, bbox= box_style)
ax4=plt.text(4, 10.5,'svar_y1: 4.13', fontsize = 15, bbox=box_style)
ax5=plt.text(4, 10.0, 'corr: 0.82', fontsize = 15, bbox=box_style)

plt.ylabel('y data', fontsize=20)
plt.xlabel('x data', fontsize=20)

ax.plot(xseq, a + b * xseq, color="k", lw=2.5);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Ex 6A-4 Loading from json
# * Load the file *data4.json* to a dataframe named `df4`. Be sure to view the json. You may need to make some modification for it to form a similar dataframe as the previous data files.
# * The two data columns should be named `x4` and `y4` and are the first row in the file.
# * Use pandas' describe() to those two variables.
# * Calculate a variety of statistics as described in the cells below. Use any methods and functions you prefer.
# * Plot a scatter plot of the two variables.
# * Overlay a regression line on the plot calculated from the two variables.
# * Add annotations so that the means, sample variances, correlation, and regression equation are in a box in the upper left corner of the figure.

# %% [markdown]
# * **IMPORTANT - MOST COMMON REASON FOR DEDUCTIONS:** Check the index values of this dataframe. If the index starts with 1 instead of 0, be sure to **reset the index** so that it matches the other dataframes. Double-check to be sure your changes weren't temporary otherwise, you'll end up with many missing values in the combined dataframe.

# %%
# Load the data file to a data frame named df4. 

file4 = 'data4.json'
df4 = pd.read_json(file4)

newdf4 = df4.reset_index()

newdf4
# Out:
#     index  x4     y4
# 0       1   8   6.58
# 1       2   8   5.76
# 2       3   8   7.71
# 3       4   8   8.84
# 4       5   8   8.47
# 5       6   8   7.04
# 6       7   8   5.25
# 7       8  19  12.50
# 8       9   8   5.56
# 9      10   8   7.91
# 10     11   8   6.89

# %%
# describe the series in the dataframe

df4.describe()
# Out:
#               x4         y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
# Calculate the following by replacing the 0 with some formula.

mean_x4 = df4['x4'].mean()       # mean
mean_y4 = df4['y4'].mean()       # mean
svar_x4 = df4['x4'].mean()       # sample variance
svar_y4 = df4['y4'].mean()       # sample variance
corr_x4y4 = df4['x4'].corr(df4['y4'])     # correlation

# %%
# Print out the results (Do not change this code)
print(f'mean_x4: {mean_x4:.3f}\tmean_y4: {mean_y4:.3f}')     # mean'
print(f'svar_x4: {svar_x4:.3f}\tsvar_y4: {svar_y4:.3f}') 
print(f'corr: {corr_x4y4:.3f}')
# Out:
# mean_x4: 9.000	mean_y4: 7.501
# svar_x4: 9.000	svar_y4: 7.501
# corr: 0.817

# %%
X4 = df4['x4']
Y4 = df4['y4']
plt.scatter(X4,Y4);

# %%
x4 = df4['x4'].tolist()
y4 = df4['y4'].tolist()

print(x4)
print(y4)
# Out:
# [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
# [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.5600000000000005, 7.91, 6.89]

# %%
slope4, intercept4, r4, p4, std_err4 = stats.linregress(x4, y4)

# %%
print('slope4: ' + str(slope4))
print('intercept4: ' + str(intercept4))
print('r4: ' + str(r4))
print('p4: ' + str(p4))
print('std_err4: ' + str(std_err4))
# Out:
# slope4: 0.4999090909090909
# intercept4: 3.0017272727272726
# r4: 0.8165214368885028
# p4: 0.002164602347197222
# std_err4: 0.11781894172968553

# %%
# Calculate a linear regression line;  capture the following results
d4_const = intercept4     # regression line constant
x4_coef = slope4     # x coefficient

# %%
# Print out the results of the regression equation (Do not change this code)
print(f'y = {d4_const:.2f} + {x4_coef:.2f}x')
# Out:
# y = 3.00 + 0.50x

# %%
# Plot it!
# plot x and y as a scatter plot  (dots should be green)
# On the same chart, plot the regression line without marker (line should be black)
# Choose any style you desire, include x and y axis labels and a title that includes the file name
# Annotate with a box in the upper left corner of the grid as described above

fig, ax = plt.subplots(figsize = (10, 10))
plt.xticks (fontsize= 20 ) 
plt.yticks (fontsize= 20 )

ax.scatter(x4, y4, s=100, color="g")

b, a = np.polyfit(x4, y4, deg=1)

xseq = np.linspace(8, 19)

plt.title('data4.json', fontsize = 30)

ax1= plt.text(4, 12.5, 'mean_x4: 9.00', fontsize = 15, bbox= box_style)
ax2= plt.text(4, 12.0, 'mean_y4: 7.50', fontsize = 15, bbox= box_style)
ax3=plt.text(4, 11.5, 'svar_x4: 11.00', fontsize = 15, bbox= box_style)
ax4=plt.text(4, 11.0,'svar_y4: 4.13', fontsize = 15, bbox=box_style)
ax5=plt.text(4, 10.5, 'corr: 0.82', fontsize = 15, bbox=box_style)

plt.ylabel('y data', fontsize=20)
plt.xlabel('x data', fontsize=20)

ax.plot(xseq, a + b * xseq, color="k", lw=2.5);

# %% [markdown]
# ![image.png](attachment:image.png)
